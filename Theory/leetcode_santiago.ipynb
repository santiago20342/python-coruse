# %% [markdown]
# 1. Two Sum<br>
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
#
#
# Example 1:
#
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]

# %%
from IPython.display import Image
Image(filename='asc_table.png')

# %% [markdown]
# <!-- <img scr="asc_table.png" alt="not working"></img> -->

# %%
my_list = list(range(97,103))
letter_list =[]
for number in my_list:
    # print(chr(number))
    letter_list.append(chr(number))
numbers = list(range(0,6))
index = len(letter_list)-1
for i, letter in enumerate(letter_list):
    for number in letter_list:
        # print(letter_list[i],letter_list[i + 1])
        print(letter,letter[2::])
        # print(letter,number)
# Out:
# a
# a
# a
# a
# a
# a
# b
# b
# b
# b
# b
# b
# c
# c
# c
# c
# c
# c
# d
# d
# d
# d
# d
# d
# e
# e
# e
# e
# e
# e
# f
# f
# f
# f
# f
# f

# %%
number_list = list(range(0,6))
letter_list = ['a','b','c','d','e','f']
for letter in letter_list:
    for number in number_list:
        print(letter,number)
# Out:
# a 0
# a 1
# a 2
# a 3
# a 4
# a 5
# b 0
# b 1
# b 2
# b 3
# b 4
# b 5
# c 0
# c 1
# c 2
# c 3
# c 4
# c 5
# d 0
# d 1
# d 2
# d 3
# d 4
# d 5
# e 0
# e 1
# e 2
# e 3
# e 4
# e 5
# f 0
# f 1
# f 2
# f 3
# f 4
# f 5

# %%
number_list = list(range(0,6))
letter_list = ['a','b','c','d','e','f']
for letter in letter_list:
    for number in letter_list:
        print(letter,number)
# Out:
# a a
# a b
# a c
# a d
# a e
# a f
# b a
# b b
# b c
# b d
# b e
# b f
# c a
# c b
# c c
# c d
# c e
# c f
# d a
# d b
# d c
# d d
# d e
# d f
# e a
# e b
# e c
# e d
# e e
# e f
# f a
# f b
# f c
# f d
# f e
# f f

# %%
number_list = list(range(0,6))
letter_list = ['a','b','c','d','e','f']
counter = 1
for index in range(len(letter_list)):
    print('first index', letter_list[index])
    for index2 in range(len(letter_list)):
        print('first index: ', index, 'second index: ', index2, 'letter: ', letter_list[index2], 'combination: ', letter_list[index] + letter_list[index2], 'counter: ', counter)
        counter += 1
# Out:
# first index a
# first index:  0 second index:  0 letter:  a combination:  aa counter:  1
# first index:  0 second index:  1 letter:  b combination:  ab counter:  2
# first index:  0 second index:  2 letter:  c combination:  ac counter:  3
# first index:  0 second index:  3 letter:  d combination:  ad counter:  4
# first index:  0 second index:  4 letter:  e combination:  ae counter:  5
# first index:  0 second index:  5 letter:  f combination:  af counter:  6
# first index b
# first index:  1 second index:  0 letter:  a combination:  ba counter:  7
# first index:  1 second index:  1 letter:  b combination:  bb counter:  8
# first index:  1 second index:  2 letter:  c combination:  bc counter:  9
# first index:  1 second index:  3 letter:  d combination:  bd counter:  10
# first index:  1 second index:  4 letter:  e combination:  be counter:  11
# first index:  1 second index:  5 letter:  f combination:  bf counter:  12
# first index c
# ...

# %%
number_list = list(range(0,6))
letter_list = ['a','b','c','d','e','f']
counter = 1
for index in range(len(letter_list)):
    print('first index', letter_list[index])
    for index2 in range(index, len(letter_list)):
        print('first index: ', index, 'second index: ', index2, 'letter: ', letter_list[index2], 'combination: ', letter_list[index] + letter_list[index2], 'counter: ', counter)
        counter += 1
# Out:
# first index a
# first index:  0 second index:  0 letter:  a combination:  aa counter:  1
# first index:  0 second index:  1 letter:  b combination:  ab counter:  2
# first index:  0 second index:  2 letter:  c combination:  ac counter:  3
# first index:  0 second index:  3 letter:  d combination:  ad counter:  4
# first index:  0 second index:  4 letter:  e combination:  ae counter:  5
# first index:  0 second index:  5 letter:  f combination:  af counter:  6
# first index b
# first index:  1 second index:  1 letter:  b combination:  bb counter:  7
# first index:  1 second index:  2 letter:  c combination:  bc counter:  8
# first index:  1 second index:  3 letter:  d combination:  bd counter:  9
# first index:  1 second index:  4 letter:  e combination:  be counter:  10
# first index:  1 second index:  5 letter:  f combination:  bf counter:  11
# first index c
# first index:  2 second index:  2 letter:  c combination:  cc counter:  12
# ...

# %%
#bruteforce approach to Leetcode Ex. 1
class Solution:
    def twoSum(self, nums: list[int], target: int):
        nums = [5,8,10,11,14]
        target = 15
        for number in nums:
            for number2 in nums:
                if (number + number2) == target:
                    print(number, number2)
#check the fisrt 2 numbers added togoether will the get target
#check the first 1 and 3 number added together will get the target 

sol = Solution()
sol.twoSum([5,8,10,11,14], 15)
# Out:
# 5 10
# 10 5
